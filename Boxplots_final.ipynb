# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.ticker as ticker

salaries = pd.read_csv('salaries.csv')

# %%
# Define a mapping from experience_level to experience_desc
experience_mapping = {'EN': 'Entry', 'MI': 'Middle', 'SE': 'Senior', 'EX': 'Executive'}

# Create a new column 'experience_desc' using the mapping
salaries['experience_desc'] = salaries['experience_level'].map(experience_mapping)

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               SE              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               MI              FT
# ...         ...              ...             ...
# 8540       2020               SE              FT
# 8541       2021               MI              FT
# 8542       2020               EN              FT
# 8543       2020               EN              CT
# 8544       2021               SE              FT
#
#                             job_title   salary salary_currency  salary_in_usd  \
# 0                       Data Engineer   166000             USD         166000
# 1                       Data Engineer    73100             USD          73100
# 2     Business Intelligence Developer   140000             USD         140000
# 3     Business Intelligence Developer   110000             USD         110000
# 4                      Data Scientist   130900             USD         130900
# ...                               ...      ...             ...            ...
# 8540                   Data Scientist   412000             USD         412000
# 8541         Principal Data Scientist   151000             USD         151000
# 8542                   Data Scientist   105000             USD         105000
# 8543            Business Data Analyst   100000             USD         100000
# 8544             Data Science Manager  7000000             INR          94665
#
#      employee_residence  remote_ratio company_location company_size  \
# 0                    US             0               US            M
# 1                    US             0               US            M
# 2                    US           100               US            M
# 3                    US           100               US            M
# 4                    US             0               US            M
# ...                 ...           ...              ...          ...
# 8540                 US           100               US            L
# 8541                 US           100               US            L
# 8542                 US           100               US            S
# 8543                 US           100               US            L
# 8544                 IN            50               IN            L
#
#      experience_desc
# 0             Senior
# 1             Senior
# 2             Middle
# 3             Middle
# 4             Middle
# ...              ...
# 8540          Senior
# 8541          Middle
# 8542           Entry
# 8543           Entry
# 8544          Senior
#
# [8545 rows x 12 columns]

# %%
# Define the order of experience levels
experience_order = ['Entry', 'Middle', 'Senior', 'Executive']

# Convert 'experience_level' to a categorical variable with the desired order
salaries['experience_level'] = pd.Categorical(salaries['experience_desc'], categories=experience_order, ordered=True)

# Set the style of seaborn for better aesthetics (optional)
sns.set(style="whitegrid")

# Create a boxplot for each experience level
plt.figure(figsize=(6,8))
sns.boxplot(x='experience_level', y='salary_in_usd', data=salaries, palette="Set3")

#Set y-axis limits
plt.ylim(0, 500000)

# Customize the plot
plt.xlabel("")
plt.ylabel("")

# Format y-axis labels as 100k, 200k, etc.
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('${x:,.0f}'))


# Show the plot
plt.savefig('exp_boxplot.png', bbox_inches = 'tight', facecolor = 'white')
plt.show()
# Out:
# /tmp/ipykernel_388/3452923608.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='experience_level', y='salary_in_usd', data=salaries, palette="Set3")
